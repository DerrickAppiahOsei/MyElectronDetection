# %%
import tensorflow as tf
import numpy as np
import h5py
from tensorflow.keras import layers, models, optimizers
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split


# Configure Keras to use GPU
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(sess)
# Out:
# 2024-09-09 15:40:24.102435: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-09 15:40:24.136051: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-09 15:40:24.136080: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-09 15:40:24.136107: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-09 15:40:24.142937: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-09 15:40:24.928862: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-09-09 15:40:26.717064: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21410 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:68:00.0, compute capability: 8.6

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import h5py
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, callbacks

class DataLoader:
    def __init__(self, h5_filename):
        self.h5_filename = h5_filename
        self.images, self.centers = self.load_data()

    def load_data(self):
        with h5py.File(self.h5_filename, 'r') as f:
            images = np.array(f['images'])
            centers = np.array(f['centers_training'])
        return images, centers

    def plot_image_with_centers(self, image_index=None):
        if image_index is None:
            image_index = np.random.randint(0, len(self.images))

        image = self.images[image_index]
        centers = self.centers[image_index]

        plt.imshow(image, cmap='gray')
        valid_centers = centers[centers[:, 0] == 1]
        for center in valid_centers:
            plt.scatter(center[1], center[2], c='red', marker='x')  # center[1] is x and center[2] is y
        plt.title('Image with Valid Centers Marked')
        plt.colorbar()
        plt.show()

    @staticmethod
    def sort_centers(centers):
        return centers[np.lexsort((centers[:, 0], centers[:, 1]))]

    def normalize_data(self):
        normalized_images = self.images / np.max(self.images)
        sorted_centers = np.array([self.sort_centers(image_centers[:, 1:]) for image_centers in self.centers])
        normalized_centers = sorted_centers / 64
        normalized_midpoints = tf.expand_dims(normalized_centers, axis=1)
        return normalized_images, normalized_midpoints.numpy()

    def split_data(self, train_size=0.82, random_state=42):
        normalized_images, normalized_midpoints_np = self.normalize_data()
        return train_test_split(normalized_images, normalized_midpoints_np, train_size=train_size, random_state=random_state)


class ModelBuilder:
    def __init__(self, input_shape=(64, 64, 1), num_classes=3, num_coordinates=2, learning_rate=1e-3):
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.num_coordinates = num_coordinates
        self.learning_rate = learning_rate
        self.model = self.build_model()
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=self.learning_rate)

    def build_model(self):
        x_input = layers.Input(shape=self.input_shape)
        x = layers.Conv2D(64, kernel_size=3, padding='same', activation='relu')(x_input)
        x = layers.MaxPool2D()(x)
        x = layers.BatchNormalization()(x)
        x = layers.Conv2D(64, kernel_size=3, padding='same', activation='relu')(x)
        
        x = layers.Conv2D(128, kernel_size=3, padding='same', activation='relu')(x)
        x = layers.Conv2D(128, kernel_size=3, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.3)(x)
        
        x = layers.Conv2D(256, kernel_size=3, padding='same', activation='relu')(x)
        x = layers.Conv2D(256, kernel_size=3, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.3)(x)
        
        x = layers.Conv2D(512, kernel_size=3, padding='same', activation='relu')(x)
        x = layers.MaxPool2D()(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.4)(x)
        x = layers.Conv2D(512, kernel_size=3, padding='same', activation='relu')(x)
        x = layers.MaxPool2D()(x)
        x = layers.BatchNormalization()(x)
        x = layers.Conv2D(512, kernel_size=3, padding='same', activation='relu')(x)
        x = layers.MaxPool2D()(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.4)(x)
        
        x = layers.Conv2D(256, kernel_size=5, padding='same', activation='relu')(x)
        x = layers.MaxPool2D()(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.4)(x)
        
        x = layers.Flatten()(x)
        
        x_midpoints = layers.Dense(self.num_classes * self.num_coordinates, activation='sigmoid', name='x_midpoints')(x)
        x_midpoints_reshape = layers.Reshape((-1, self.num_classes, self.num_coordinates), name='x_midpoints_reshape')(x_midpoints)
        
        return tf.keras.models.Model(x_input, x_midpoints_reshape)

    def compile_model(self, loss_function):
        self.model.compile(optimizer=self.optimizer, loss=loss_function)

    def train_model(self, train_dataset, val_dataset, epochs, callbacks_list):
        history = self.model.fit(train_dataset, epochs=epochs, validation_data=val_dataset, callbacks=callbacks_list)
        return history


@tf.keras.utils.register_keras_serializable()
class DynamicExponentCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_exponent=3, increment=1, update_frequency=10):
        super().__init__()
        self.exponent = initial_exponent
        self.increment = increment
        self.update_frequency = update_frequency

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.update_frequency == 0:
            self.exponent += self.increment
            print(f"\nEpoch {epoch + 1}: Increasing exponent to {self.exponent}")
            self.model.loss = self.custom_loss(self.exponent)

    def custom_loss(self, exponent):
        def loss(y_true, y_pred):
            diff = tf.abs(y_true - y_pred)
            powered_diff = tf.pow(diff, exponent)
            return tf.reduce_mean(powered_diff)
        return loss

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'initial_exponent': self.exponent,
            'increment': self.increment,
            'update_frequency': self.update_frequency,
        })
        return config


class CustomModelCheckpoint(callbacks.Callback):
    def __init__(self, save_freq, save_path):
        super(CustomModelCheckpoint, self).__init__()
        self.save_freq = save_freq
        self.save_path = save_path

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.save_freq == 0:
            self.model.save(self.save_path.format(epoch=epoch + 1))
            print(f"Model saved at epoch {epoch + 1}")

# %%
# Initialize the DataLoader with the path to the HDF5 file
h5_filename = '/home/m3-learning/Documents/Research Data/Electron Detection/Data Generated/data before organization/Padded_120KMixedImages.h5'

# h5_filename = '/home/m3-learning/Documents/Research Data/Electron Detection/Data Generated/100KMixedImages.h5'


data_loader = DataLoader(h5_filename)

# Load images and centers
images, centers = data_loader.load_data()

# %%
# Optional: Plot a random image with valid centers marked
data_loader.plot_image_with_centers()

# %%
# Normalize the data and split it into training and validation sets
train_images, val_images, train_midpoints, val_midpoints = data_loader.split_data()

# Check the shape of the datasets
print(f'Train Images: {train_images.shape}, Train Midpoints: {train_midpoints.shape}')
print(f'Validation Images: {val_images.shape}, Validation Midpoints: {val_midpoints.shape}')
# Out:
# 2024-09-09 15:41:25.568498: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21410 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:68:00.0, compute capability: 8.6
# Train Images: (98400, 64, 64), Train Midpoints: (98400, 1, 3, 2)
# Validation Images: (21600, 64, 64), Validation Midpoints: (21600, 1, 3, 2)

# %%
# Convert the data to TensorFlow datasets
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_midpoints))
val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_midpoints))

# Batch and shuffle the datasets
batch_size = 800
train_dataset = train_dataset.shuffle(buffer_size=2000, reshuffle_each_iteration=True).batch(batch_size)
val_dataset = val_dataset.shuffle(buffer_size=2000).batch(batch_size)

# %%
# Initialize the ModelBuilder
model_builder = ModelBuilder()

# Build the model
model = model_builder.build_model()

# Display the model architecture
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  conv2d_10 (Conv2D)          (None, 64, 64, 64)        640
#
#  max_pooling2d_5 (MaxPoolin  (None, 32, 32, 64)        0
#  g2D)
#
#  batch_normalization_7 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 64)        36928
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 128)       73856
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 128)       147584
#
#  batch_normalization_8 (Bat  (None, 32, 32, 128)       512
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 32, 32, 128)       0
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 256)       295168
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 256)       590080
#
#  batch_normalization_9 (Bat  (None, 32, 32, 256)       1024
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 32, 32, 256)       0
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 512)       1180160
#
#  max_pooling2d_6 (MaxPoolin  (None, 16, 16, 512)       0
#  g2D)
#
#  batch_normalization_10 (Ba  (None, 16, 16, 512)       2048
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 16, 16, 512)       0
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 512)       2359808
#
#  max_pooling2d_7 (MaxPoolin  (None, 8, 8, 512)         0
#  g2D)
#
#  batch_normalization_11 (Ba  (None, 8, 8, 512)         2048
#  tchNormalization)
#
#  conv2d_18 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  max_pooling2d_8 (MaxPoolin  (None, 4, 4, 512)         0
#  g2D)
#
#  batch_normalization_12 (Ba  (None, 4, 4, 512)         2048
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 4, 4, 512)         0
#
#  conv2d_19 (Conv2D)          (None, 4, 4, 256)         3277056
#
#  max_pooling2d_9 (MaxPoolin  (None, 2, 2, 256)         0
#  g2D)
#
#  batch_normalization_13 (Ba  (None, 2, 2, 256)         1024
#  tchNormalization)
#
#  dropout_9 (Dropout)         (None, 2, 2, 256)         0
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  x_midpoints (Dense)         (None, 6)                 6150
#
#  x_midpoints_reshape (Resha  (None, 1, 3, 2)           0
#  pe)
#
# =================================================================
# Total params: 10336198 (39.43 MB)
# Trainable params: 10331718 (39.41 MB)
# Non-trainable params: 4480 (17.50 KB)
# _________________________________________________________________

# %%
# # Initialize the dynamic exponent callback
# dynamic_exponent_callback = DynamicExponentCallback(initial_exponent=2, increment=1, update_frequency=7)

# # Compile the model with the custom loss function
# model_builder.compile_model(loss_function=dynamic_exponent_callback.custom_loss(2))

# %%
# Define the save path for the model checkpoints
save_path = "/home/da886/ElectronCountingProject/weights for custom loss/customlossmodel_epoch_{epoch:02d}.h5"
checkpoint_callback = CustomModelCheckpoint(save_freq=200, save_path=save_path)

# Define the learning rate scheduler
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=7, verbose=1, mode='min', min_lr=7e-15
)

# %%
model_builder.compile_model(loss_function=tf.keras.losses.MeanSquaredError())

# %%
# Train the model
history = model_builder.train_model(
    train_dataset, val_dataset, epochs=310, callbacks_list=[lr_scheduler]
)
# Out:
# Epoch 1/310
# 2024-09-01 16:22:51.443031: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-09-01 16:22:51.785821: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-09-01 16:22:58.598194: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7a7b2003a8a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-09-01 16:22:58.598238: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2024-09-01 16:22:58.610543: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-01 16:22:58.740251: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-09-01 16:23:00.812177: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 7.84GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-09-01 16:23:02.025267: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 5.19GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-09-01 16:23:02.811110: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 7.65GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-09-01 16:23:06.105493: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 7.88GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 123/123 [==============================] - 111s 700ms/step - loss: 0.0364 - val_loss: 0.1032 - lr: 0.0010
# Epoch 2/310
# 123/123 [==============================] - 82s 669ms/step - loss: 0.0176 - val_loss: 0.0577 - lr: 0.0010
# Epoch 3/310
# 123/123 [==============================] - 84s 686ms/step - loss: 0.0142 - val_loss: 0.0310 - lr: 0.0010
# Epoch 4/310
# 123/123 [==============================] - 88s 717ms/step - loss: 0.0133 - val_loss: 0.0148 - lr: 0.0010
# Epoch 5/310
# 123/123 [==============================] - 92s 752ms/step - loss: 0.0129 - val_loss: 0.0155 - lr: 0.0010
# Epoch 6/310
# 123/123 [==============================] - 93s 754ms/step - loss: 0.0126 - val_loss: 0.0149 - lr: 0.0010
# Epoch 7/310
# 123/123 [==============================] - 94s 766ms/step - loss: 0.0124 - val_loss: 0.0141 - lr: 0.0010
# Epoch 8/310
# 123/123 [==============================] - 95s 771ms/step - loss: 0.0123 - val_loss: 0.0135 - lr: 0.0010
# Epoch 9/310
# 123/123 [==============================] - 94s 768ms/step - loss: 0.0122 - val_loss: 0.0133 - lr: 0.0010
# Epoch 10/310
# 123/123 [==============================] - 95s 769ms/step - loss: 0.0122 - val_loss: 0.0137 - lr: 0.0010
# Epoch 11/310
# 123/123 [==============================] - 94s 768ms/step - loss: 0.0121 - val_loss: 0.0137 - lr: 0.0010
# Epoch 12/310
# 123/123 [==============================] - 95s 770ms/step - loss: 0.0121 - val_loss: 0.0133 - lr: 0.0010
# Epoch 13/310
# 123/123 [==============================] - 95s 770ms/step - loss: 0.0120 - val_loss: 0.0117 - lr: 0.0010
# Epoch 14/310
# 123/123 [==============================] - 95s 772ms/step - loss: 0.0119 - val_loss: 0.0130 - lr: 0.0010
# Epoch 15/310
# 123/123 [==============================] - 95s 771ms/step - loss: 0.0119 - val_loss: 0.0118 - lr: 0.0010
# Epoch 16/310
# 123/123 [==============================] - 91s 744ms/step - loss: 0.0119 - val_loss: 0.0140 - lr: 0.0010
# Epoch 17/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0118 - val_loss: 0.0149 - lr: 0.0010
# Epoch 18/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0118 - val_loss: 0.0124 - lr: 0.0010
# Epoch 19/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0118 - val_loss: 0.0207 - lr: 0.0010
# Epoch 20/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0118
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 123/123 [==============================] - 77s 627ms/step - loss: 0.0118 - val_loss: 0.0118 - lr: 0.0010
# Epoch 21/310
# 123/123 [==============================] - 77s 627ms/step - loss: 0.0115 - val_loss: 0.0118 - lr: 5.0000e-04
# Epoch 22/310
# 123/123 [==============================] - 77s 627ms/step - loss: 0.0115 - val_loss: 0.0118 - lr: 5.0000e-04
# Epoch 23/310
# 123/123 [==============================] - 77s 627ms/step - loss: 0.0115 - val_loss: 0.0117 - lr: 5.0000e-04
# Epoch 24/310
# 123/123 [==============================] - 77s 627ms/step - loss: 0.0114 - val_loss: 0.0113 - lr: 5.0000e-04
# Epoch 25/310
# 123/123 [==============================] - 77s 627ms/step - loss: 0.0115 - val_loss: 0.0122 - lr: 5.0000e-04
# Epoch 26/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0114 - val_loss: 0.0126 - lr: 5.0000e-04
# Epoch 27/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0114 - val_loss: 0.0163 - lr: 5.0000e-04
# Epoch 28/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0114 - val_loss: 0.0128 - lr: 5.0000e-04
# Epoch 29/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0114 - val_loss: 0.0119 - lr: 5.0000e-04
# Epoch 30/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0114 - val_loss: 0.0124 - lr: 5.0000e-04
# Epoch 31/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0114
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0114 - val_loss: 0.0126 - lr: 5.0000e-04
# Epoch 32/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0112 - val_loss: 0.0119 - lr: 2.5000e-04
# Epoch 33/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0111 - val_loss: 0.0138 - lr: 2.5000e-04
# Epoch 34/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0111 - val_loss: 0.0130 - lr: 2.5000e-04
# Epoch 35/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0110 - val_loss: 0.0130 - lr: 2.5000e-04
# Epoch 36/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0110 - val_loss: 0.0120 - lr: 2.5000e-04
# Epoch 37/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0110 - val_loss: 0.0123 - lr: 2.5000e-04
# Epoch 38/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0110
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0110 - val_loss: 0.0204 - lr: 2.5000e-04
# Epoch 39/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0108 - val_loss: 0.0125 - lr: 1.2500e-04
# Epoch 40/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0107 - val_loss: 0.0126 - lr: 1.2500e-04
# Epoch 41/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0106 - val_loss: 0.0160 - lr: 1.2500e-04
# Epoch 42/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0106 - val_loss: 0.0127 - lr: 1.2500e-04
# Epoch 43/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0105 - val_loss: 0.0129 - lr: 1.2500e-04
# Epoch 44/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0105 - val_loss: 0.0545 - lr: 1.2500e-04
# Epoch 45/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 45: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0104 - val_loss: 0.0909 - lr: 1.2500e-04
# Epoch 46/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0103 - val_loss: 0.0223 - lr: 6.2500e-05
# Epoch 47/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0102 - val_loss: 0.0469 - lr: 6.2500e-05
# Epoch 48/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0101 - val_loss: 0.0302 - lr: 6.2500e-05
# Epoch 49/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0101 - val_loss: 0.0200 - lr: 6.2500e-05
# Epoch 50/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0100 - val_loss: 0.0291 - lr: 6.2500e-05
# Epoch 51/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0099 - val_loss: 0.0127 - lr: 6.2500e-05
# Epoch 52/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0099
# Epoch 52: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0099 - val_loss: 0.0165 - lr: 6.2500e-05
# Epoch 53/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0099 - val_loss: 0.0123 - lr: 3.1250e-05
# Epoch 54/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0098 - val_loss: 0.0123 - lr: 3.1250e-05
# Epoch 55/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0098 - val_loss: 0.0123 - lr: 3.1250e-05
# Epoch 56/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0097 - val_loss: 0.0126 - lr: 3.1250e-05
# Epoch 57/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0097 - val_loss: 0.0123 - lr: 3.1250e-05
# Epoch 58/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0097 - val_loss: 0.0123 - lr: 3.1250e-05
# Epoch 59/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0096
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0096 - val_loss: 0.0126 - lr: 3.1250e-05
# Epoch 60/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0095 - val_loss: 0.0123 - lr: 1.5625e-05
# Epoch 61/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0096 - val_loss: 0.0122 - lr: 1.5625e-05
# Epoch 62/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0094 - val_loss: 0.0123 - lr: 1.5625e-05
# Epoch 63/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0095 - val_loss: 0.0123 - lr: 1.5625e-05
# Epoch 64/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0094 - val_loss: 0.0123 - lr: 1.5625e-05
# Epoch 65/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0094 - val_loss: 0.0124 - lr: 1.5625e-05
# Epoch 66/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 66: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0094 - val_loss: 0.0123 - lr: 1.5625e-05
# Epoch 67/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0094 - val_loss: 0.0123 - lr: 7.8125e-06
# Epoch 68/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0093 - val_loss: 0.0123 - lr: 7.8125e-06
# Epoch 69/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0093 - val_loss: 0.0123 - lr: 7.8125e-06
# Epoch 70/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0093 - val_loss: 0.0123 - lr: 7.8125e-06
# Epoch 71/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0093 - val_loss: 0.0123 - lr: 7.8125e-06
# Epoch 72/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0093 - val_loss: 0.0123 - lr: 7.8125e-06
# Epoch 73/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0093
# Epoch 73: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0093 - val_loss: 0.0123 - lr: 7.8125e-06
# Epoch 74/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 3.9063e-06
# Epoch 75/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 3.9063e-06
# Epoch 76/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 3.9063e-06
# Epoch 77/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 3.9063e-06
# Epoch 78/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 3.9063e-06
# Epoch 79/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 3.9063e-06
# Epoch 80/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 3.9063e-06
# Epoch 81/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.9531e-06
# Epoch 82/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.9531e-06
# Epoch 83/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.9531e-06
# Epoch 84/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.9531e-06
# Epoch 85/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.9531e-06
# Epoch 86/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.9531e-06
# Epoch 87/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 87: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.9531e-06
# Epoch 88/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 9.7656e-07
# Epoch 89/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 9.7656e-07
# Epoch 90/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 9.7656e-07
# Epoch 91/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 9.7656e-07
# Epoch 92/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 9.7656e-07
# Epoch 93/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 9.7656e-07
# Epoch 94/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 94: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 9.7656e-07
# Epoch 95/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 4.8828e-07
# Epoch 96/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 4.8828e-07
# Epoch 97/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 4.8828e-07
# Epoch 98/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 4.8828e-07
# Epoch 99/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 4.8828e-07
# Epoch 100/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 4.8828e-07
# Epoch 101/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 101: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 4.8828e-07
# Epoch 102/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.4414e-07
# Epoch 103/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 2.4414e-07
# Epoch 104/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.4414e-07
# Epoch 105/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.4414e-07
# Epoch 106/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.4414e-07
# Epoch 107/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.4414e-07
# Epoch 108/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 108: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 2.4414e-07
# Epoch 109/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.2207e-07
# Epoch 110/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.2207e-07
# Epoch 111/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.2207e-07
# Epoch 112/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.2207e-07
# Epoch 113/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.2207e-07
# Epoch 114/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.2207e-07
# Epoch 115/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 115: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.2207e-07
# Epoch 116/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 6.1035e-08
# Epoch 117/310
# 123/123 [==============================] - 77s 624ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 6.1035e-08
# Epoch 118/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 6.1035e-08
# Epoch 119/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 6.1035e-08
# Epoch 120/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 6.1035e-08
# Epoch 121/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 6.1035e-08
# Epoch 122/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 122: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 6.1035e-08
# Epoch 123/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 3.0518e-08
# Epoch 124/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 3.0518e-08
# Epoch 125/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 3.0518e-08
# Epoch 126/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 3.0518e-08
# Epoch 127/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 3.0518e-08
# Epoch 128/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 3.0518e-08
# Epoch 129/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 129: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 3.0518e-08
# Epoch 130/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.5259e-08
# Epoch 131/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.5259e-08
# Epoch 132/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.5259e-08
# Epoch 133/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.5259e-08
# Epoch 134/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.5259e-08
# Epoch 135/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.5259e-08
# Epoch 136/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 136: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.5259e-08
# Epoch 137/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.6294e-09
# Epoch 138/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.6294e-09
# Epoch 139/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 7.6294e-09
# Epoch 140/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.6294e-09
# Epoch 141/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 7.6294e-09
# Epoch 142/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.6294e-09
# Epoch 143/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 143: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.6294e-09
# Epoch 144/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 3.8147e-09
# Epoch 145/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 3.8147e-09
# Epoch 146/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 3.8147e-09
# Epoch 147/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 3.8147e-09
# Epoch 148/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 3.8147e-09
# Epoch 149/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 3.8147e-09
# Epoch 150/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 150: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 3.8147e-09
# Epoch 151/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.9073e-09
# Epoch 152/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.9073e-09
# Epoch 153/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.9073e-09
# Epoch 154/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.9073e-09
# Epoch 155/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.9073e-09
# Epoch 156/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.9073e-09
# Epoch 157/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 157: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.9073e-09
# Epoch 158/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 9.5367e-10
# Epoch 159/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 9.5367e-10
# Epoch 160/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 9.5367e-10
# Epoch 161/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 9.5367e-10
# Epoch 162/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 9.5367e-10
# Epoch 163/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 9.5367e-10
# Epoch 164/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 164: ReduceLROnPlateau reducing learning rate to 4.768371808516747e-10.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 9.5367e-10
# Epoch 165/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 4.7684e-10
# Epoch 166/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 4.7684e-10
# Epoch 167/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 4.7684e-10
# Epoch 168/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 4.7684e-10
# Epoch 169/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 4.7684e-10
# Epoch 170/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 4.7684e-10
# Epoch 171/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 171: ReduceLROnPlateau reducing learning rate to 2.3841859042583735e-10.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 4.7684e-10
# Epoch 172/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.3842e-10
# Epoch 173/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 2.3842e-10
# Epoch 174/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.3842e-10
# Epoch 175/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.3842e-10
# Epoch 176/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.3842e-10
# Epoch 177/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.3842e-10
# Epoch 178/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 178: ReduceLROnPlateau reducing learning rate to 1.1920929521291868e-10.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.3842e-10
# Epoch 179/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.1921e-10
# Epoch 180/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.1921e-10
# Epoch 181/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.1921e-10
# Epoch 182/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.1921e-10
# Epoch 183/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.1921e-10
# Epoch 184/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.1921e-10
# Epoch 185/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 185: ReduceLROnPlateau reducing learning rate to 5.960464760645934e-11.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.1921e-10
# Epoch 186/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 5.9605e-11
# Epoch 187/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 5.9605e-11
# Epoch 188/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 5.9605e-11
# Epoch 189/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 5.9605e-11
# Epoch 190/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 5.9605e-11
# Epoch 191/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 5.9605e-11
# Epoch 192/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 192: ReduceLROnPlateau reducing learning rate to 2.980232380322967e-11.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 5.9605e-11
# Epoch 193/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 2.9802e-11
# Epoch 194/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.9802e-11
# Epoch 195/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.9802e-11
# Epoch 196/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 2.9802e-11
# Epoch 197/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 2.9802e-11
# Epoch 198/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.9802e-11
# Epoch 199/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 199: ReduceLROnPlateau reducing learning rate to 1.4901161901614834e-11.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.9802e-11
# Epoch 200/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.4901e-11
# Epoch 201/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.4901e-11
# Epoch 202/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.4901e-11
# Epoch 203/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.4901e-11
# Epoch 204/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.4901e-11
# Epoch 205/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.4901e-11
# Epoch 206/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 206: ReduceLROnPlateau reducing learning rate to 7.450580950807417e-12.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.4901e-11
# Epoch 207/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 7.4506e-12
# Epoch 208/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.4506e-12
# Epoch 209/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 7.4506e-12
# Epoch 210/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 7.4506e-12
# Epoch 211/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.4506e-12
# Epoch 212/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 7.4506e-12
# Epoch 213/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 213: ReduceLROnPlateau reducing learning rate to 3.725290475403709e-12.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.4506e-12
# Epoch 214/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 3.7253e-12
# Epoch 215/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 3.7253e-12
# Epoch 216/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 3.7253e-12
# Epoch 217/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 3.7253e-12
# Epoch 218/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 3.7253e-12
# Epoch 219/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 3.7253e-12
# Epoch 220/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 220: ReduceLROnPlateau reducing learning rate to 1.8626452377018543e-12.
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 3.7253e-12
# Epoch 221/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.8626e-12
# Epoch 222/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.8626e-12
# Epoch 223/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.8626e-12
# Epoch 224/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.8626e-12
# Epoch 225/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.8626e-12
# Epoch 226/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.8626e-12
# Epoch 227/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 227: ReduceLROnPlateau reducing learning rate to 9.313226188509272e-13.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.8626e-12
# Epoch 228/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 9.3132e-13
# Epoch 229/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 9.3132e-13
# Epoch 230/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 9.3132e-13
# Epoch 231/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 9.3132e-13
# Epoch 232/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 9.3132e-13
# Epoch 233/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 9.3132e-13
# Epoch 234/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 234: ReduceLROnPlateau reducing learning rate to 4.656613094254636e-13.
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 9.3132e-13
# Epoch 235/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 4.6566e-13
# Epoch 236/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 4.6566e-13
# Epoch 237/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 4.6566e-13
# Epoch 238/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 4.6566e-13
# Epoch 239/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 4.6566e-13
# Epoch 240/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 4.6566e-13
# Epoch 241/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 241: ReduceLROnPlateau reducing learning rate to 2.328306547127318e-13.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 4.6566e-13
# Epoch 242/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 2.3283e-13
# Epoch 243/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 2.3283e-13
# Epoch 244/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.3283e-13
# Epoch 245/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.3283e-13
# Epoch 246/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 2.3283e-13
# Epoch 247/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.3283e-13
# Epoch 248/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 248: ReduceLROnPlateau reducing learning rate to 1.164153273563659e-13.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.3283e-13
# Epoch 249/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.1642e-13
# Epoch 250/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.1642e-13
# Epoch 251/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.1642e-13
# Epoch 252/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.1642e-13
# Epoch 253/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.1642e-13
# Epoch 254/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.1642e-13
# Epoch 255/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 255: ReduceLROnPlateau reducing learning rate to 5.820766367818295e-14.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.1642e-13
# Epoch 256/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 5.8208e-14
# Epoch 257/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 5.8208e-14
# Epoch 258/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 5.8208e-14
# Epoch 259/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 5.8208e-14
# Epoch 260/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 5.8208e-14
# Epoch 261/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 5.8208e-14
# Epoch 262/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 262: ReduceLROnPlateau reducing learning rate to 2.9103831839091474e-14.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 5.8208e-14
# Epoch 263/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.9104e-14
# Epoch 264/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.9104e-14
# Epoch 265/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 2.9104e-14
# Epoch 266/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.9104e-14
# Epoch 267/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 2.9104e-14
# Epoch 268/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 2.9104e-14
# Epoch 269/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 269: ReduceLROnPlateau reducing learning rate to 1.4551915919545737e-14.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 2.9104e-14
# Epoch 270/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.4552e-14
# Epoch 271/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.4552e-14
# Epoch 272/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.4552e-14
# Epoch 273/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.4552e-14
# Epoch 274/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 1.4552e-14
# Epoch 275/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.4552e-14
# Epoch 276/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 276: ReduceLROnPlateau reducing learning rate to 7.275957959772868e-15.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 1.4552e-14
# Epoch 277/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.2760e-15
# Epoch 278/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.2760e-15
# Epoch 279/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.2760e-15
# Epoch 280/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.2760e-15
# Epoch 281/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.2760e-15
# Epoch 282/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.2760e-15
# Epoch 283/310
# 123/123 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 283: ReduceLROnPlateau reducing learning rate to 7e-15.
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.2760e-15
# Epoch 284/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 285/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 286/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 287/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 288/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 289/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 290/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 291/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 292/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 293/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 294/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 295/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 296/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 297/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 298/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 299/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 300/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 301/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 302/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 303/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 304/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 305/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 306/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 307/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0092 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 308/310
# 123/123 [==============================] - 77s 626ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 309/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15
# Epoch 310/310
# 123/123 [==============================] - 77s 625ms/step - loss: 0.0091 - val_loss: 0.0123 - lr: 7.0000e-15

# %%
# Extract the losses from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']


train_loss_x_midpoints = history.history.get('x_midpoints_reshape_loss', train_loss)
val_loss_x_midpoints = history.history.get('val_x_midpoints_reshape_loss', val_loss)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2,1)
plt.plot(train_loss_x_midpoints, label='Train Loss x_midpoints_reshape')
plt.plot(val_loss_x_midpoints, label='Validation Loss x_midpoints_reshape')
plt.xlabel('Epochs')
plt.yscale('log')

plt.ylabel('Loss')
plt.title('Training and Validation Loss ')
plt.legend()

plt.tight_layout()
plt.show()

# %%
loadedmodel = tf.keras.models.load_model('/home/m3-learning/Documents/Research Data/Electron Detection/Weights/Weights for overfitting/Classescopy_0903_increaseddropouts_Padded100Kimages.h5')###this is for varied labels

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Define the function for visualizing midpoints
def visualize_midpoints(image, midpoints, title="Predicted Midpoint Visualization"):
    """
    Visualizes midpoints on an image without using a probability vector.

    Parameters:
    - image: A 3D tensor representing the image.
    - midpoints: A 2D tensor representing the midpoint coordinates (x, y).
    - title: The title of the plot.

    Returns:
    None (displays the image with midpoints).
    """
    # Convert to NumPy arrays for easier handling
    image_np = image
    midpoints_np = midpoints

    # Denormalize image if necessary (adjust based on your normalization method)
    denormalized_image = image_np  # Modify if normalization was applied during training

    # Visualize the image
    plt.figure(figsize=(4, 4))
    plt.imshow(denormalized_image, cmap='gray')
    plt.title(title)

    # Plot midpoints directly, only if they are not (0, 0)
    for i, (x, y) in enumerate(midpoints_np):
        if x >= 3 and y >= 3:  # Only plot if the point is not (0, 0)
            plt.scatter(x, y, color='red', s=5)

    plt.show()

# Create the validation dataset
# val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_midpoints))
# val_dataset = val_dataset.batch(800)
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_midpoints))
train_dataset = train_dataset.batch(800)

# Initialize lists to collect the data
all_images = []
all_true_midpoints = []
all_pred_midpoints = []

# Loop through each batch in the validation dataset, predict, and collect results
# for i, (data_batch, midpoints_batch) in enumerate(val_dataset):
for i, (data_batch, midpoints_batch) in enumerate(train_dataset):
    print(f"Processing batch {i + 1}, batch shape: {data_batch.shape}")
    
    # Get the model predictions
    predictions = loadedmodel.predict(data_batch)

    # Extend the lists to store data from each batch
    all_images.extend(data_batch.numpy())  # Store all images
    all_true_midpoints.extend(midpoints_batch.numpy())  # Store all true midpoints
    all_pred_midpoints.extend(predictions)  # Store all predicted midpoints

# Convert lists to arrays for easier indexing
all_images = np.array(all_images)
all_true_midpoints = np.array(all_true_midpoints)
all_pred_midpoints = np.array(all_pred_midpoints)
# Out:
# Processing batch 1, batch shape: (800, 64, 64)
# 2024-09-09 15:41:59.989521: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 25/25 [==============================] - 2s 9ms/step
# Processing batch 2, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 3, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 4, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 5, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 6, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 7, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 8, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 9, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 8ms/step
# Processing batch 10, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 11, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 12, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 13, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 14, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 15, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 16, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 17, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 8ms/step
# Processing batch 18, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 19, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 20, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 21, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 22, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 23, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 24, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 25, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 26, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 27, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 28, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 29, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 30, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 31, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 32, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 33, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 8ms/step
# Processing batch 34, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 35, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 36, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 37, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 38, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 39, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 40, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 41, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 42, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 43, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 44, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 45, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 46, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 47, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 48, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 49, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 50, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 51, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 52, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 53, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 54, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 55, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 8ms/step
# Processing batch 56, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 57, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 58, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 59, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 60, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 61, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 62, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 63, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 64, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 65, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 66, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 67, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 68, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 69, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 70, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 71, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 72, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 73, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 74, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 75, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 76, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 77, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 78, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 79, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 8ms/step
# Processing batch 80, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 81, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 82, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 8ms/step
# Processing batch 83, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 84, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 85, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 8ms/step
# Processing batch 86, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 87, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 88, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 8ms/step
# Processing batch 89, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 90, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 91, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 92, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 93, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 94, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 95, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 8ms/step
# Processing batch 96, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 8ms/step
# Processing batch 97, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 98, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 99, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 100, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 101, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 102, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 103, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 8ms/step
# Processing batch 104, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 105, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 106, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 107, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 108, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 109, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 110, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 111, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 112, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 8ms/step
# Processing batch 113, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 114, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 115, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 8ms/step
# Processing batch 116, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 117, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 118, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 119, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 10ms/step
# Processing batch 120, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 121, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step
# Processing batch 122, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 8ms/step
# Processing batch 123, batch shape: (800, 64, 64)
# 25/25 [==============================] - 0s 9ms/step

# %%
# Select an index to visualize from the entire dataset
index_to_visualize = np.random.randint(0, len(all_images))


# Visualize the selected image with predicted and true midpoints
visualize_midpoints(all_images[index_to_visualize], all_pred_midpoints[index_to_visualize, 0, :, :] * 64, title="Predicted Midpoints")
visualize_midpoints(all_images[index_to_visualize], all_true_midpoints[index_to_visualize, 0, :, :] * 64, title="Ground Truth Midpoints")

# %%
import numpy as np
import matplotlib.pyplot as plt

# Initialize variables to track the min and max MSE
min_mse = float('inf')
max_mse = float('-inf')
min_mse_index = -1
max_mse_index = -1

# Loop through each prediction to calculate the MSE
for i in range(len(all_pred_midpoints)):
    mse = np.mean((all_pred_midpoints[i] - all_true_midpoints[i]) ** 2)
    
    if mse < min_mse:
        min_mse = mse
        min_mse_index = i
    
    if mse > max_mse:
        max_mse = mse
        max_mse_index = i


# Function to plot an image with its centers
def plot_image_with_centers(image, true_center, predicted_center, title):
    plt.figure(figsize=(5, 5))
    plt.imshow(image.squeeze(), cmap='gray')  # Display the image

    # Plot the actual center (Groundtruth)
    plt.scatter(true_center[:, 0], true_center[:, 1], color='green', label='Groundtruth', s=10)

    # Plot the predicted center
    plt.scatter(predicted_center[:, 0], predicted_center[:, 1], color='red', label='Predictions', s=10)

    plt.title(title)
    plt.legend()
    plt.show()






# Plotting the image with the least MSE
plot_image_with_centers(all_images[min_mse_index],
                        all_true_midpoints[min_mse_index][0] * 64,  
                        all_pred_midpoints[min_mse_index][0] * 64,  
                        f'Image with Least MSE. MSE: {min_mse:.4f}')

# Plotting the image with the largest MSE
plot_image_with_centers(all_images[max_mse_index],
                        all_true_midpoints[max_mse_index][0] * 64, 
                        all_pred_midpoints[max_mse_index][0] * 64,  
                        f'Image with Largest MSE. MSE: {max_mse:.4f}')

# %%
val_loss = loadedmodel.evaluate(val_dataset)
val_loss
# Out:
# 27/27 [==============================] - 10s 196ms/step - loss: 0.0123
# 0.012341718189418316

# %%
train_loss = loadedmodel.evaluate(train_dataset)
# Out:
# 123/123 [==============================] - 25s 191ms/step - loss: 0.0081

# %%
# train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_midpoints))
# train_dataset = train_dataset.batch(800)
# inputs,targets = next(iter(train_dataset))
# output =model_builder.model.predict(inputs)

# val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_midpoints))
# val_dataset = val_dataset.batch(800)
# inputs,targets = next(iter(val_dataset))
# output =loadedmodel.predict(inputs)
# Out:
# 25/25 [==============================] - 0s 9ms/step

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# def visualize_midpoints(image, midpoints):
#     """
#     Visualizes midpoints on an image without using a probability vector.

#     Parameters:
#     - image: A 3D tensor representing the image.
#     - midpoints: A 2D tensor representing the midpoint coordinates (x, y).

#     Returns:
#     None (displays the image with midpoints).
#     """
#     # Convert to NumPy arrays for easier handling
#     image_np = image
#     midpoints_np = midpoints

#     # Denormalize image if necessary (adjust based on your normalization method)
#     denormalized_image = image_np  # Modify if normalization was applied during training

#     # Visualize the image
#     plt.figure(figsize=(4, 4))
#     plt.imshow(denormalized_image, cmap='gray')
#     plt.title("Predicted Midpoint Visualization")

#     # Plot midpoints directly
#     for i, (x, y) in enumerate(midpoints_np):
#         plt.scatter(x, y, color='red', s=5)

#     plt.show()

# def visualize_midpoints2(image, midpoints):
#     """
#     Visualizes ground truth midpoints on an image without using a probability vector.

#     Parameters:
#     - image: A 3D tensor representing the image.
#     - midpoints: A 2D tensor representing the midpoint coordinates (x, y).

#     Returns:
#     None (displays the image with midpoints).
#     """
    
#     image_np = image
#     midpoints_np = midpoints 
#     denormalized_image = image_np 

#     # Visualize the image
#     plt.figure(figsize=(4, 4))
#     plt.imshow(denormalized_image, cmap='gray')
#     plt.title("Ground Truth Midpoint Visualization")

#     # Plot midpoints directly
#     for i, (x, y) in enumerate(midpoints_np):
#         plt.scatter(x, y, color='red', s=5)

#     plt.show()

# # Example usage with random data
# t = np.random.randint(0, 800)
# # t=100

# visualize_midpoints(tf.convert_to_tensor(inputs[t]), tf.convert_to_tensor(output[t,0,:,:])*64)
# visualize_midpoints2(tf.convert_to_tensor(inputs[t]), tf.convert_to_tensor(targets[t,0,:,:])*64)

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# def visualize_midpoints(image, midpoints):
#     """
#     Visualizes midpoints on an image without using a probability vector.

#     Parameters:
#     - image: A 3D tensor representing the image.
#     - midpoints: A 2D tensor representing the midpoint coordinates (x, y).

#     Returns:
#     None (displays the image with midpoints).
#     """
#     # Convert to NumPy arrays for easier handling
#     image_np = image
#     midpoints_np = midpoints

#     # Denormalize image if necessary (adjust based on your normalization method)
#     denormalized_image = image_np  # Modify if normalization was applied during training

#     # Visualize the image
#     plt.figure(figsize=(4, 4))
#     plt.imshow(denormalized_image, cmap='gray')
#     plt.title("Predicted Midpoint Visualization")

#     # Plot midpoints directly, only if they are not (0, 0)
#     for i, (x, y) in enumerate(midpoints_np):
#         if x >= 3 and y >= 3:  # Only plot if the point is not (0, 0)
#             plt.scatter(x, y, color='red', s=5)

#     plt.show()

# def visualize_midpoints2(image, midpoints):
#     """
#     Visualizes ground truth midpoints on an image without using a probability vector.

#     Parameters:
#     - image: A 3D tensor representing the image.
#     - midpoints: A 2D tensor representing the midpoint coordinates (x, y).

#     Returns:
#     None (displays the image with midpoints).
#     """
#     image_np = image
#     midpoints_np = midpoints
#     denormalized_image = image_np 

#     # Visualize the image
#     plt.figure(figsize=(4, 4))
#     plt.imshow(denormalized_image, cmap='gray')
#     plt.title("Ground Truth Midpoint Visualization")

#     # Plot midpoints directly, only if they are not (0, 0)
#     for i, (x, y) in enumerate(midpoints_np):
#         # if x != 0 and y != 0:  # Only plot if the point is not (0, 0)
#         if x >= 3 and y >= 3:
#             plt.scatter(x, y, color='red', s=5)

#     plt.show()

# # Example usage with random data
# t = np.random.randint(0, 800)
# # t=100

# visualize_midpoints(tf.convert_to_tensor(inputs[t]), tf.convert_to_tensor(output[t,0,:,:])*64)
# visualize_midpoints2(tf.convert_to_tensor(inputs[t]), tf.convert_to_tensor(targets[t,0,:,:])*64)

# %%
# model_builder.model.save('/home/m3-learning/Documents/Research Data/Electron Detection/Weights/Weights for overfitting/Classescopy_0903_increaseddropouts_Padded100Kimages.h5')

# %%
# train_loss = model_builder.model.evaluate(train_images, train_midpoints, verbose=0)

# %%
# train_loss
# Out:
# 0.008115575648844242

# %%
# val_loss = model_builder.model.evaluate(val_dataset)
# val_loss
# Out:
# 27/27 [==============================] - 5s 192ms/step - loss: 0.0123
# 0.012341722846031189

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_midpoints))
train_dataset = train_dataset.batch(800)
inputs,targets = next(iter(train_dataset))
# output =model_builder.model.predict(inputs)
# val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_midpoints))
# val_dataset = val_dataset.batch(800)

# # Get the inputs and targets from the dataset
# inputs, targets = next(iter(val_dataset))

# Make predictions using the model
predictions = model_builder.model.predict(inputs)

# Squeeze the singleton dimension at index 1 from both predictions and targets
predictions = np.squeeze(predictions, axis=1)
targets = np.squeeze(targets, axis=1)

# Initialize variables to track the min and max MSE
min_mse = float('inf')
max_mse = float('-inf')
min_mse_index = -1
max_mse_index = -1

# Loop through each prediction to calculate the MSE
for i in range(len(predictions)):
    mse = np.mean((predictions[i] - targets[i]) ** 2)
    
    if mse < min_mse:
        min_mse = mse
        min_mse_index = i
    
    if mse > max_mse:
        max_mse = mse
        max_mse_index = i

# Function to plot an image with its centers
def plot_image_with_centers(image, true_center, predicted_center, title):
    plt.figure(figsize=(5, 5))
    plt.imshow(image.squeeze(), cmap='gray')  

    # Plot the actual center
    plt.scatter(true_center[:, 0], true_center[:, 1], color='green', label='Groundtruth', s=10)

    # Plot the predicted center
    plt.scatter(predicted_center[:, 0], predicted_center[:, 1], color='red', label='Predictions', s=10)

    plt.title(title)
    plt.legend()
    plt.show()

# Convert inputs to numpy arrays for plotting
inputs_np = inputs.numpy()

# Plotting the image with the least MSE
plot_image_with_centers(inputs_np[min_mse_index],
                        targets[min_mse_index]*64,
                        predictions[min_mse_index]*64,
                        f'Image with Least MSE. MSE: {min_mse:.4f}')

# Plotting the image with the largest MSE
plot_image_with_centers(inputs_np[max_mse_index],
                        targets[max_mse_index]*64,
                        predictions[max_mse_index]*64,
                        f'Image with Largest MSE. MSE: {max_mse:.4f}')
# Out:
# 25/25 [==============================] - 0s 8ms/step
