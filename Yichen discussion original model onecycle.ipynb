# %%
import tensorflow as tf
import numpy as np
import h5py
from tensorflow.keras import layers, models, optimizers
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split


# Configure Keras to use GPU
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(sess)
# Out:
# 2024-09-11 12:49:28.067847: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-11 12:49:28.114944: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-11 12:49:28.114981: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-11 12:49:28.115006: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-11 12:49:28.121574: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-11 12:49:29.074234: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-09-11 12:49:31.563648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12318 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:68:00.0, compute capability: 8.6

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import h5py
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, callbacks

class DataLoader:
    def __init__(self, h5_filename):
        self.h5_filename = h5_filename
        self.images, self.centers = self.load_data()

    def load_data(self):
        with h5py.File(self.h5_filename, 'r') as f:
            images = np.array(f['images'])
            centers = np.array(f['centers_training'])
        return images, centers

    def plot_image_with_centers(self, image_index=None):
        if image_index is None:
            image_index = np.random.randint(0, len(self.images))

        image = self.images[image_index]
        centers = self.centers[image_index]

        plt.imshow(image, cmap='gray')
        valid_centers = centers[centers[:, 0] == 1]
        for center in valid_centers:
            plt.scatter(center[1], center[2], c='red', marker='x')  # center[1] is x and center[2] is y
        plt.title('Image with Valid Centers Marked')
        plt.colorbar()
        plt.show()

    @staticmethod
    def sort_centers(centers):
        return centers[np.lexsort((centers[:, 0], centers[:, 1]))]

    def normalize_data(self):
        normalized_images = self.images / np.max(self.images)
        sorted_centers = np.array([self.sort_centers(image_centers[:, 1:]) for image_centers in self.centers])
        normalized_centers = sorted_centers / 64
        normalized_midpoints = tf.expand_dims(normalized_centers, axis=1)
        return normalized_images, normalized_midpoints.numpy()

    def split_data(self, train_size=0.82, random_state=42):
        normalized_images, normalized_midpoints_np = self.normalize_data()
        return train_test_split(normalized_images, normalized_midpoints_np, train_size=train_size, random_state=random_state)


class ModelBuilder:
    def __init__(self, input_shape=(64, 64, 1), num_classes=5, num_coordinates=2, learning_rate=3e-5, weights_path=None):
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.num_coordinates = num_coordinates
        self.learning_rate = learning_rate
        self.model = self.build_model()

        # Load weights if a path is provided
        if weights_path is not None:
            self.model.load_weights(weights_path)

        self.optimizer = tf.keras.optimizers.Adam(learning_rate=self.learning_rate)
        # self.optimizer =tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)

    def build_model(self):
        x_input = layers.Input(shape=self.input_shape)
        x = layers.Conv2D(128, kernel_size=3, padding='same', activation='relu')(x_input)
        x = layers.MaxPool2D()(x)
        x = layers.BatchNormalization()(x)
        x = layers.Conv2D(128, kernel_size=3, padding='same', activation='relu')(x)
        
        x = layers.Conv2D(256, kernel_size=3, padding='same', activation='relu')(x)
        x = layers.Conv2D(256, kernel_size=3, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.2)(x)
        
        x = layers.Conv2D(512, kernel_size=3, padding='same', activation='relu')(x)
        x = layers.Conv2D(512, kernel_size=3, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.2)(x)
        
        x = layers.Conv2D(1024, kernel_size=3, padding='same', activation='relu')(x)
        x = layers.MaxPool2D()(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.3)(x)
        x = layers.Conv2D(1024, kernel_size=3, padding='same', activation='relu')(x)
        x = layers.MaxPool2D()(x)
        x = layers.BatchNormalization()(x)
        x = layers.Conv2D(1024, kernel_size=3, padding='same', activation='relu')(x)
        x = layers.MaxPool2D()(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.3)(x)
        
        x = layers.Conv2D(512, kernel_size=5, padding='same', activation='relu')(x)
        x = layers.MaxPool2D()(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.3)(x)
        
        x = layers.Flatten()(x)
        
        x_midpoints = layers.Dense(self.num_classes * self.num_coordinates, activation='sigmoid', name='x_midpoints')(x)
        x_midpoints_reshape = layers.Reshape((-1, self.num_classes, self.num_coordinates), name='x_midpoints_reshape')(x_midpoints)
        
        return tf.keras.models.Model(x_input, x_midpoints_reshape)

    def compile_model(self, loss_function):
        self.model.compile(optimizer=self.optimizer, loss=loss_function)

    def train_model(self, train_dataset, val_dataset, epochs, callbacks_list):
        history = self.model.fit(train_dataset, epochs=epochs, validation_data=val_dataset, callbacks=callbacks_list)
        return history

# %%
# Initialize the DataLoader with the path to the HDF5 file
h5_filename = '/home/m3-learning/Documents/Research Data/Electron Detection/Data Generated/Fixed hits/5 only/30KFixed_Mixed_5.h5'




data_loader = DataLoader(h5_filename)

# Load images and centers
images, centers = data_loader.load_data()

# %%
# Optional: Plot a random image with valid centers marked
data_loader.plot_image_with_centers()

# %%
# Normalize the data and split it into training and validation sets
train_images, val_images, train_midpoints, val_midpoints = data_loader.split_data()

# Check the shape of the datasets
print(f'Train Images: {train_images.shape}, Train Midpoints: {train_midpoints.shape}')
print(f'Validation Images: {val_images.shape}, Validation Midpoints: {val_midpoints.shape}')
# Out:
# 2024-09-11 12:50:27.844219: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12318 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:68:00.0, compute capability: 8.6
# Train Images: (24600, 64, 64), Train Midpoints: (24600, 1, 5, 2)
# Validation Images: (5400, 64, 64), Validation Midpoints: (5400, 1, 5, 2)

# %%
# Convert the data to TensorFlow datasets
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_midpoints))
val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_midpoints))

# %%
# Batch and shuffle the datasets
batch_size = 200
train_dataset = train_dataset.shuffle(buffer_size=2000, reshuffle_each_iteration=True).batch(batch_size)
val_dataset = val_dataset.shuffle(buffer_size=2000).batch(batch_size)

# %%
batches =next(iter(train_dataset))
batches[0].shape
# Out:
# TensorShape([200, 64, 64])

# %%
# Initialize the ModelBuilder
model_builder = ModelBuilder()

# Build the model
model = model_builder.build_model()

# Display the model architecture
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  conv2d_10 (Conv2D)          (None, 64, 64, 128)       1280
#
#  max_pooling2d_5 (MaxPoolin  (None, 32, 32, 128)       0
#  g2D)
#
#  batch_normalization_7 (Bat  (None, 32, 32, 128)       512
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 128)       147584
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 256)       295168
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 256)       590080
#
#  batch_normalization_8 (Bat  (None, 32, 32, 256)       1024
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 32, 32, 256)       0
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 512)       1180160
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 512)       2359808
#
#  batch_normalization_9 (Bat  (None, 32, 32, 512)       2048
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 32, 32, 512)       0
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 1024)      4719616
#
#  max_pooling2d_6 (MaxPoolin  (None, 16, 16, 1024)      0
#  g2D)
#
#  batch_normalization_10 (Ba  (None, 16, 16, 1024)      4096
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 16, 16, 1024)      0
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 1024)      9438208
#
#  max_pooling2d_7 (MaxPoolin  (None, 8, 8, 1024)        0
#  g2D)
#
#  batch_normalization_11 (Ba  (None, 8, 8, 1024)        4096
#  tchNormalization)
#
#  conv2d_18 (Conv2D)          (None, 8, 8, 1024)        9438208
#
#  max_pooling2d_8 (MaxPoolin  (None, 4, 4, 1024)        0
#  g2D)
#
#  batch_normalization_12 (Ba  (None, 4, 4, 1024)        4096
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 4, 4, 1024)        0
#
#  conv2d_19 (Conv2D)          (None, 4, 4, 512)         13107712
#
#  max_pooling2d_9 (MaxPoolin  (None, 2, 2, 512)         0
#  g2D)
#
#  batch_normalization_13 (Ba  (None, 2, 2, 512)         2048
#  tchNormalization)
#
#  dropout_9 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  x_midpoints (Dense)         (None, 10)                20490
#
#  x_midpoints_reshape (Resha  (None, 1, 5, 2)           0
#  pe)
#
# =================================================================
# Total params: 41316234 (157.61 MB)
# Trainable params: 41307274 (157.57 MB)
# Non-trainable params: 8960 (35.00 KB)
# _________________________________________________________________

# %%
train_outputs = model_builder.model.predict(train_images)
val_outputs = model_builder.model.predict(val_images)
# Out:
# 2024-09-11 12:31:07.592457: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 769/769 [==============================] - 6s 6ms/step
# 169/169 [==============================] - 1s 5ms/step

# %%
train_outputs.shape, val_outputs.shape
# Out:
# ((24600, 1, 5, 2), (5400, 1, 5, 2))

# %%
import tensorflow as tf
import numpy as np

# Define One Cycle Learning Rate function
def one_cycle_lr(epoch, total_epochs, max_lr, min_lr, total_steps):
    mid_epoch = total_epochs // 2
    if epoch < mid_epoch:
        lr = min_lr + (max_lr - min_lr) * epoch / mid_epoch
    else:
        lr = max_lr - (max_lr - min_lr) * (epoch - mid_epoch) / (total_epochs - mid_epoch)
    return lr

# Create a learning rate scheduler callback
class OneCycleLR(tf.keras.callbacks.Callback):
    def __init__(self, max_lr, min_lr, total_epochs, total_steps):
        super(OneCycleLR, self).__init__()
        self.max_lr = max_lr
        self.min_lr = min_lr
        self.total_epochs = total_epochs
        self.total_steps = total_steps

    def on_epoch_begin(self, epoch, logs=None):
        lr = one_cycle_lr(epoch, self.total_epochs, self.max_lr, self.min_lr, self.total_steps)
        tf.keras.backend.set_value(self.model.optimizer.lr, lr)
        print(f"Setting learning rate to: {lr}")


# Set your total epochs, max learning rate, and min learning rate
total_epochs = 20
total_steps = len(train_dataset) # Assuming steps per epoch for the dataset
max_lr = 1e-3
min_lr = 3e-9

# Apply One Cycle Learning Rate scheduler
one_cycle_scheduler = OneCycleLR(max_lr=max_lr, min_lr=min_lr, total_epochs=total_epochs, total_steps=total_steps)

# %%
total_steps
# Out:
# 123

# %%
model_builder.compile_model(loss_function=tf.keras.losses.MeanSquaredError())

# %%
# Train the model
history = model_builder.train_model(
    train_dataset, val_dataset, epochs=100, callbacks_list=[one_cycle_scheduler]
)
# Out:
# Setting learning rate to: 3e-09
# Epoch 1/100
# 2024-09-11 12:50:53.764708: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-09-11 12:50:54.053568: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-09-11 12:51:04.947414: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7a80000241c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-09-11 12:51:04.947446: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2024-09-11 12:51:04.953053: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-11 12:51:05.040648: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-09-11 12:51:07.371705: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-09-11 12:51:10.647395: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.35GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-09-11 12:51:17.059180: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 5.82GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-09-11 12:51:22.729098: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 5.83GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#   6/123 [>.............................] - ETA: 1:50 - loss: 0.1209WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.3488s vs `on_train_batch_end` time: 0.4957s). Check your callbacks.
# 123/123 [==============================] - 161s 1s/step - loss: 0.1215 - val_loss: 0.0736
# Setting learning rate to: 0.00010000270000000002
# Epoch 2/100
# 123/123 [==============================] - 125s 1s/step - loss: 0.0716 - val_loss: 0.0519
# Setting learning rate to: 0.00020000240000000001
# Epoch 3/100
# 123/123 [==============================] - 124s 1s/step - loss: 0.0311 - val_loss: 0.0404
# Setting learning rate to: 0.00030000210000000004
# Epoch 4/100
# 123/123 [==============================] - 125s 1s/step - loss: 0.0209 - val_loss: 0.0303
# Setting learning rate to: 0.00040000180000000004
# Epoch 5/100
# 123/123 [==============================] - 125s 1s/step - loss: 0.0190 - val_loss: 0.0496
# Setting learning rate to: 0.0005000015000000001
# Epoch 6/100
# 123/123 [==============================] - 125s 1s/step - loss: 0.0181 - val_loss: 0.0196
# Setting learning rate to: 0.0006000012000000001
# Epoch 7/100
# 123/123 [==============================] - 125s 1s/step - loss: 0.0164 - val_loss: 0.0158
# Setting learning rate to: 0.0007000009000000001
# Epoch 8/100
# 123/123 [==============================] - 126s 1s/step - loss: 0.0199 - val_loss: 0.2250
# Setting learning rate to: 0.0008000006000000001
# Epoch 9/100
# 123/123 [==============================] - 110s 896ms/step - loss: 0.0180 - val_loss: 0.0149
# Epoch 30/100
# 123/123 [==============================] - 62s 504ms/step - loss: 0.4443 - val_loss: 0.4464
# Setting learning rate to: -0.0009999940000000001
# Epoch 31/100
# 123/123 [==============================] - 63s 513ms/step - loss: 0.4447 - val_loss: 0.4444
# Setting learning rate to: -0.0010999937000000003
# Epoch 32/100
# 123/123 [==============================] - 64s 518ms/step - loss: 0.4454 - val_loss: 0.4455
# Setting learning rate to: -0.0011999934
# Epoch 33/100
# 123/123 [==============================] - 62s 502ms/step - loss: 0.4463 - val_loss: 0.4470
# Setting learning rate to: -0.0012999931000000002
# Epoch 34/100
# 123/123 [==============================] - 61s 495ms/step - loss: 0.4459 - val_loss: 0.4468
# Setting learning rate to: -0.0013999928000000003
# Epoch 35/100
# 123/123 [==============================] - 61s 496ms/step - loss: 0.4462 - val_loss: 0.4472
# Setting learning rate to: -0.0014999925
# Epoch 36/100
# 123/123 [==============================] - 63s 512ms/step - loss: 0.4470 - val_loss: 0.4484
# Setting learning rate to: -0.0015999922000000002
# Epoch 37/100
# 123/123 [==============================] - 63s 511ms/step - loss: 0.4470 - val_loss: 0.4413
# Setting learning rate to: -0.0016999919
# Epoch 38/100
# 123/123 [==============================] - 62s 505ms/step - loss: 0.4478 - val_loss: 0.4480
# Setting learning rate to: -0.0017999916000000001
# Epoch 39/100
# 123/123 [==============================] - 63s 512ms/step - loss: 0.4477 - val_loss: 0.4471
# Setting learning rate to: -0.0018999913000000003
# Epoch 40/100
# 123/123 [==============================] - 63s 510ms/step - loss: 0.4478 - val_loss: 0.4468
# Setting learning rate to: -0.001999991
# Epoch 41/100
# 123/123 [==============================] - 63s 509ms/step - loss: 0.4469 - val_loss: 0.4431
# Setting learning rate to: -0.0020999907
# Epoch 42/100
# 123/123 [==============================] - 63s 509ms/step - loss: 0.4469 - val_loss: 0.4470
# Setting learning rate to: -0.0021999904000000003
# Epoch 43/100
# 123/123 [==============================] - 63s 511ms/step - loss: 0.4481 - val_loss: 0.4461
# Setting learning rate to: -0.0022999901000000005
# Epoch 44/100
# 123/123 [==============================] - 62s 504ms/step - loss: 0.4474 - val_loss: 0.4464
# Setting learning rate to: -0.0023999898
# Epoch 45/100
# 123/123 [==============================] - 63s 515ms/step - loss: 0.4479 - val_loss: 0.4471
# Setting learning rate to: -0.0024999895000000004
# Epoch 46/100
# 123/123 [==============================] - 65s 530ms/step - loss: 0.4479 - val_loss: 0.4488
# Setting learning rate to: -0.0025999892000000005
# Epoch 47/100
# 123/123 [==============================] - 64s 524ms/step - loss: 0.4485 - val_loss: 0.4484
# Setting learning rate to: -0.0026999889000000003
# Epoch 48/100
# 123/123 [==============================] - 63s 515ms/step - loss: 0.4474 - val_loss: 0.4463
# Setting learning rate to: -0.0027999886000000004
# Epoch 49/100
# 123/123 [==============================] - 63s 512ms/step - loss: 0.4475 - val_loss: 0.4462
# Setting learning rate to: -0.0028999883000000006
# Epoch 50/100
# Setting learning rate to: -0.004999982
# Epoch 71/100
# 123/123 [==============================] - 63s 510ms/step - loss: 0.4475 - val_loss: 0.4471
# Setting learning rate to: -0.005099981700000001
# Epoch 72/100
# 123/123 [==============================] - 61s 500ms/step - loss: 0.4475 - val_loss: 0.4463
# Setting learning rate to: -0.0051999814
# Epoch 73/100
# 123/123 [==============================] - 62s 501ms/step - loss: 0.4472 - val_loss: 0.4461
# Setting learning rate to: -0.0052999811
# Epoch 74/100
# 123/123 [==============================] - 63s 513ms/step - loss: 0.4462 - val_loss: 0.3747
# Setting learning rate to: -0.005399980800000001
# Epoch 75/100
# 123/123 [==============================] - 66s 535ms/step - loss: 0.4459 - val_loss: 0.4469
# Setting learning rate to: -0.0054999805
# Epoch 76/100
# 123/123 [==============================] - 63s 512ms/step - loss: 0.4476 - val_loss: 0.4466
# Setting learning rate to: -0.005599980200000001
# Epoch 77/100
# 123/123 [==============================] - 63s 513ms/step - loss: 0.4463 - val_loss: 0.4475
# Setting learning rate to: -0.0056999799
# Epoch 78/100
# 123/123 [==============================] - 62s 507ms/step - loss: 0.4470 - val_loss: 0.4470
# Setting learning rate to: -0.0057999796000000005
# Epoch 79/100
# 123/123 [==============================] - 63s 509ms/step - loss: 0.4470 - val_loss: 0.4391
# Setting learning rate to: -0.0058999793
# Epoch 80/100
# 123/123 [==============================] - 63s 514ms/step - loss: 0.4455 - val_loss: 0.4223
# Setting learning rate to: -0.005999979000000001
# Epoch 81/100
# 123/123 [==============================] - 62s 507ms/step - loss: 0.4466 - val_loss: 0.4452
# Setting learning rate to: -0.0060999787000000005
# Epoch 82/100
# 123/123 [==============================] - 61s 497ms/step - loss: 0.4467 - val_loss: 0.4455
# Setting learning rate to: -0.006199978400000001
# Epoch 83/100
# 123/123 [==============================] - 62s 507ms/step - loss: 0.4460 - val_loss: 0.4465
# Setting learning rate to: -0.0062999781
# Epoch 84/100
# 123/123 [==============================] - 63s 510ms/step - loss: 0.4445 - val_loss: 0.3626
# Setting learning rate to: -0.0063999778000000005
# Epoch 85/100
# 123/123 [==============================] - 62s 505ms/step - loss: 0.4471 - val_loss: 0.4469
# Setting learning rate to: -0.0064999775
# Epoch 86/100
# 123/123 [==============================] - 61s 498ms/step - loss: 0.4460 - val_loss: 0.4434
# Setting learning rate to: -0.006599977200000001
# Epoch 87/100
# 123/123 [==============================] - 61s 494ms/step - loss: 0.4464 - val_loss: 0.4463
# Setting learning rate to: -0.006699976900000001
# Epoch 88/100
# 123/123 [==============================] - 61s 494ms/step - loss: 0.4453 - val_loss: 0.4445
# Setting learning rate to: -0.006799976600000001
# Epoch 89/100
# 123/123 [==============================] - 61s 494ms/step - loss: 0.4469 - val_loss: 0.4476
# Setting learning rate to: -0.0068999763
# Epoch 90/100
# 123/123 [==============================] - 61s 494ms/step - loss: 0.4467 - val_loss: 0.4463
# Setting learning rate to: -0.006999976000000001
# Epoch 91/100
# 123/123 [==============================] - 61s 494ms/step - loss: 0.4463 - val_loss: 0.4455
# Setting learning rate to: -0.007099975700000001
# Epoch 92/100
# 123/123 [==============================] - 60s 491ms/step - loss: 0.4468 - val_loss: 0.4482
# Setting learning rate to: -0.0071999754
# Epoch 93/100
# 123/123 [==============================] - 60s 491ms/step - loss: 0.4463 - val_loss: 0.4474
# Setting learning rate to: -0.007299975100000001
# Epoch 94/100
# 123/123 [==============================] - 60s 491ms/step - loss: 0.4462 - val_loss: 0.4455
# Setting learning rate to: -0.007399974800000001
# Epoch 95/100
# 123/123 [==============================] - 61s 492ms/step - loss: 0.4470 - val_loss: 0.4470
# Setting learning rate to: -0.0074999745
# Epoch 96/100
# 123/123 [==============================] - 60s 492ms/step - loss: 0.4468 - val_loss: 0.4472
# Setting learning rate to: -0.007599974200000001
# Epoch 97/100
# 123/123 [==============================] - 60s 492ms/step - loss: 0.4461 - val_loss: 0.4468
# Setting learning rate to: -0.007699973900000001
# Epoch 98/100
# 123/123 [==============================] - 60s 491ms/step - loss: 0.4451 - val_loss: 0.4465
# Setting learning rate to: -0.0077999736
# Epoch 99/100
# 123/123 [==============================] - 62s 508ms/step - loss: 0.4441 - val_loss: 0.4440
# Setting learning rate to: -0.007899973300000002
# Epoch 100/100
# 123/123 [==============================] - 61s 497ms/step - loss: 0.4446 - val_loss: 0.4461

# %%
# model.save('/home/m3-learning/Documents/Research Data/Electron Detection/Weights/Weights for Fixed/5 only/5_overfit.keras')

# %%
# Extract the losses from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']


train_loss_x_midpoints = history.history.get('x_midpoints_reshape_loss', train_loss)
val_loss_x_midpoints = history.history.get('val_x_midpoints_reshape_loss', val_loss)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2,1)
plt.plot(train_loss_x_midpoints, label='Train Loss x_midpoints_reshape')
plt.plot(val_loss_x_midpoints, label='Validation Loss x_midpoints_reshape')
plt.xlabel('Epochs')
plt.yscale('log')

plt.ylabel('Loss')
plt.title('Training and Validation Loss ')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Define the function for visualizing midpoints
def visualize_midpoints(image, midpoints, title="Predicted Midpoint Visualization"):
    """
    Visualizes midpoints on an image without using a probability vector.

    Parameters:
    - image: A 3D tensor representing the image.
    - midpoints: A 2D tensor representing the midpoint coordinates (x, y).
    - title: The title of the plot.

    Returns:
    None (displays the image with midpoints).
    """
    # Convert to NumPy arrays for easier handling
    image_np = image
    midpoints_np = midpoints

    # Denormalize image if necessary (adjust based on your normalization method)
    denormalized_image = image_np  # Modify if normalization was applied during training

    # Visualize the image
    plt.figure(figsize=(4, 4))
    plt.imshow(denormalized_image, cmap='gray')
    plt.title(title)

    # Plot midpoints directly, only if they are not (0, 0)
    for i, (x, y) in enumerate(midpoints_np):
        if x >= 3 and y >= 3:  # Only plot if the point is not (0, 0)
            plt.scatter(x, y, color='red', s=5)

    plt.show()

# Create the validation dataset
# val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_midpoints))
# val_dataset = val_dataset.batch(800)
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_midpoints))
train_dataset = train_dataset.batch(800)

# Initialize lists to collect the data
all_images = []
all_true_midpoints = []
all_pred_midpoints = []

# Loop through each batch in the validation dataset, predict, and collect results
# for i, (data_batch, midpoints_batch) in enumerate(val_dataset):
for i, (data_batch, midpoints_batch) in enumerate(train_dataset):
    print(f"Processing batch {i + 1}, batch shape: {data_batch.shape}")
    
    # Get the model predictions
    predictions = model_builder.model.predict(data_batch)

    # Extend the lists to store data from each batch
    all_images.extend(data_batch.numpy())  # Store all images
    all_true_midpoints.extend(midpoints_batch.numpy())  # Store all true midpoints
    all_pred_midpoints.extend(predictions)  # Store all predicted midpoints

# Convert lists to arrays for easier indexing
all_images = np.array(all_images)
all_true_midpoints = np.array(all_true_midpoints)
all_pred_midpoints = np.array(all_pred_midpoints)
# Out:
# Processing batch 1, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 21ms/step
# Processing batch 2, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 21ms/step
# Processing batch 3, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 21ms/step
# Processing batch 4, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 5, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 6, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 7, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 8, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 23ms/step
# Processing batch 9, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 10, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 11, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 23ms/step
# Processing batch 12, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 13, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 23ms/step
# Processing batch 14, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 15, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 16, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 17, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 18, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 19, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 20, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 21, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 23ms/step
# Processing batch 22, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 23, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 24, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 25, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 26, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 27, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 28, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 23ms/step
# Processing batch 29, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 30, batch shape: (800, 64, 64)
# 25/25 [==============================] - 1s 22ms/step
# Processing batch 31, batch shape: (600, 64, 64)
# 19/19 [==============================] - 1s 53ms/step

# %%
# Select an index to visualize from the entire dataset
index_to_visualize = np.random.randint(0, len(all_images))

# Visualize the selected image with predicted and true midpoints
visualize_midpoints(all_images[index_to_visualize], all_pred_midpoints[index_to_visualize, 0, :, :] * 64, title="Predicted Midpoints")
visualize_midpoints(all_images[index_to_visualize], all_true_midpoints[index_to_visualize, 0, :, :] * 64, title="Ground Truth Midpoints")

# %%
import numpy as np
import matplotlib.pyplot as plt

# Initialize variables to track the min and max MSE
min_mse = float('inf')
max_mse = float('-inf')
min_mse_index = -1
max_mse_index = -1

# Loop through each prediction to calculate the MSE
for i in range(len(all_pred_midpoints)):
    mse = np.mean((all_pred_midpoints[i] - all_true_midpoints[i]) ** 2)
    
    if mse < min_mse:
        min_mse = mse
        min_mse_index = i
    
    if mse > max_mse:
        max_mse = mse
        max_mse_index = i


# Function to plot an image with its centers
def plot_image_with_centers(image, true_center, predicted_center, title):
    plt.figure(figsize=(5, 5))
    plt.imshow(image.squeeze(), cmap='gray')  # Display the image

    # Plot the actual center (Groundtruth)
    plt.scatter(true_center[:, 0], true_center[:, 1], color='green', label='Groundtruth', s=10)

    # Plot the predicted center
    plt.scatter(predicted_center[:, 0], predicted_center[:, 1], color='red', label='Predictions', s=10)

    plt.title(title)
    plt.legend()
    plt.show()






# Plotting the image with the least MSE
plot_image_with_centers(all_images[min_mse_index],
                        all_true_midpoints[min_mse_index][0] * 64,  
                        all_pred_midpoints[min_mse_index][0] * 64,  
                        f'Image with Least MSE. MSE: {min_mse:.4f}')

# Plotting the image with the largest MSE
plot_image_with_centers(all_images[max_mse_index],
                        all_true_midpoints[max_mse_index][0] * 64, 
                        all_pred_midpoints[max_mse_index][0] * 64,  
                        f'Image with Largest MSE. MSE: {max_mse:.4f}')
